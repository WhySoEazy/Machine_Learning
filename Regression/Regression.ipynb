# %%
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler , OneHotEncoder , OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('StudentScore.xls')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
profile = ProfileReport(df , title = "Pandas Profiling Report", explorative=True)
profile.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 8/8 [00:00<00:00, 245.73it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
for i in df.columns:
    count = df[i].value_counts()
    plt.figure(figsize=(10, 5))
    count.plot(kind='bar')
    plt.title(f'Value Counts for {i}')
    plt.xlabel(i)
    plt.ylabel('Count')
    plt.show()
# Out:
# C:\Users\triet\AppData\Local\Temp\ipykernel_15064\182152615.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\triet\AppData\Local\Temp\ipykernel_15064\182152615.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\triet\AppData\Local\Temp\ipykernel_15064\182152615.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\triet\AppData\Local\Temp\ipykernel_15064\182152615.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\triet\AppData\Local\Temp\ipykernel_15064\182152615.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\triet\AppData\Local\Temp\ipykernel_15064\182152615.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\triet\AppData\Local\Temp\ipykernel_15064\182152615.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\triet\AppData\Local\Temp\ipykernel_15064\182152615.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# Spliting Data

# %%
target = "writing score"
x = df.drop(target , axis = 1)
y = df[target]
print(x.shape, y.shape)
# Out:
# (1000, 7) (1000,)

# %%
x_train , x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# %% [markdown]
# Transform

# %%
#transform numerical data

num_col = ['math score', 'reading score']

num_transform = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %%
#transform Ordinal data

education_values = ["some high school", "high school", "some college", "associate's degree", "bachelor's degree", "master's degree"]
lunch_values = x_train['lunch'].unique()
gender_values = x_train['gender'].unique()
test_values = x_train['test preparation course'].unique()

ord_transform = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('scaler', OrdinalEncoder(categories = [education_values, 
                                            lunch_values,
                                            gender_values,
                                            test_values]))
])

# %%
#transform nominal data

nom_col = ["race/ethnicity"]

nom_transform = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('scaler', OneHotEncoder(sparse_output=False))
])

# %% [markdown]
# Apply ColumnsTransformer

# %%
preprocessor = ColumnTransformer(transformers=[
        ('num', num_transform, num_col),
        ('ord', ord_transform, ['parental level of education', 'lunch', 'gender' , 'test preparation course']),
        ('nom', nom_transform, nom_col)
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['math score', 'reading score']),
#                                 ('ord',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('scaler',
#                                                   OrdinalEncoder(categories=[['some '
#                                                                               'high '
#                                                                               'school',
#                                                                               'high '
#                                                                               'school',
#                                                                               'some '
#                                                                               'college',
#                                                                               "associate's "
#                                                                               'degree',
#                                                                               "ba...
#                                                                               'degree'],
#                                                                              array(['standard', 'free/reduced'], dtype=object),
#                                                                              array(['male', 'female'], dtype=object),
#                                                                              array(['completed', 'none'], dtype=object)]))]),
#                                  ['parental level of education', 'lunch',
#                                   'gender', 'test preparation course']),
#                                 ('nom',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('scaler',
#                                                   OneHotEncoder(sparse_output=False))]),
#                                  ['race/ethnicity'])])

# %% [markdown]
# Modeling

# %%
reg = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LinearRegression())
])

# %%
reg.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['math score',
#                                                    'reading score']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('scaler',
#                                                                    OrdinalEncoder(categories=[['some '
#                                                                                                'high '
#                                                                                                'school',
#                                                                                                'high '
#                                                                                                'school',
#                                                                                                'some '
#                                                                                                'co...
#                                                                                               array(['standard', 'free/reduced'], dtype=object),
#                                                                                               array(['male', 'female'], dtype=object),
#                                                                                               array(['completed', 'none'], dtype=object)]))]),
#                                                   ['parental level of '
#                                                    'education',
#                                                    'lunch', 'gender',
#                                                    'test preparation course']),
#                                                  ('nom',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('scaler',
#                                                                    OneHotEncoder(sparse_output=False))]),
#                                                   ['race/ethnicity'])])),
#                 ('model', LinearRegression())])

# %%
y_pred = reg.predict(x_test)
y_pred
# Out:
# array([88.67289105, 66.50404492, 73.2173696 , 70.90618711, 79.73674645,
#        73.7679599 , 68.57747587, 62.50836852, 72.78169688, 51.17543341,
#        41.84060229, 21.86423508, 79.0260469 , 63.1143721 , 82.08157849,
#        78.80232725, 49.57508298, 47.9645953 , 57.23114693, 65.84746888,
#        71.53171194, 55.75544106, 69.30177764, 49.37376635, 77.58272974,
#        73.83057686, 73.93932607, 56.18895737, 48.74782845, 58.55020878,
#        56.75959134, 64.95659712, 59.0909488 , 66.00751226, 72.25366067,
#        52.1227874 , 74.55702568, 77.12804116, 79.58686424, 14.70704909,
#        76.55230208, 63.08422813, 65.17127171, 61.83746112, 84.21799935,
#        64.60518271, 67.08390706, 32.03731704, 86.43106722, 83.23278292,
#        72.08462324, 75.70810196, 77.59430284, 58.52505634, 71.70554635,
#        75.17197117, 78.81149468, 52.28684105, 80.39276703, 90.67564071,
#        41.45468775, 82.67788287, 79.88717053, 61.13173774, 88.72416429,
#        77.46225191, 68.77701841, 50.19052195, 68.0070307 , 93.34806422,
#        62.13560026, 87.75026658, 53.19770362, 53.30202461, 59.15616388,
#        71.74864694, 91.23521378, 52.37719081, 60.66134599, 46.8680188 ,
#        58.69727489, 36.41551717, 75.92001674, 69.80944235, 64.95325451,
#        66.08762038, 81.05925922, 70.12708482, 88.6948972 , 21.92311383,
#        77.04555391, 92.59554613, 60.22775804, 67.31376143, 35.11127805,
#        67.80765827, 59.48043641, 67.56862866, 78.34222788, 69.94176198])

# %%
for i , x in zip(y_pred , y_test):
    print("Predicted: {} - Actual: {}".format(i, x))
# Out:
# Predicted: 88.67289105107454 - Actual: 84
# Predicted: 66.50404491711782 - Actual: 73
# Predicted: 73.21736959975686 - Actual: 72
# Predicted: 70.9061871053156 - Actual: 73
# Predicted: 79.73674644539479 - Actual: 78
# Predicted: 73.76795989709788 - Actual: 78
# Predicted: 68.57747587046838 - Actual: 63
# Predicted: 62.508368521932724 - Actual: 62
# Predicted: 72.78169688316078 - Actual: 72
# Predicted: 51.17543340882495 - Actual: 41
# Predicted: 41.84060228989462 - Actual: 49
# Predicted: 21.86423507932797 - Actual: 22
# Predicted: 79.02604690031274 - Actual: 81
# Predicted: 63.11437209786499 - Actual: 61
# Predicted: 82.08157849466899 - Actual: 85
# Predicted: 78.80232725357843 - Actual: 82
# Predicted: 49.575082984729335 - Actual: 42
# Predicted: 47.96459530303818 - Actual: 44
# Predicted: 57.23114693308114 - Actual: 54
# Predicted: 65.84746887782158 - Actual: 63
# Predicted: 71.53171194494661 - Actual: 69
# Predicted: 55.755441059963694 - Actual: 54
# Predicted: 69.30177764338508 - Actual: 70
# Predicted: 49.37376634856032 - Actual: 43
# Predicted: 77.58272974139895 - Actual: 79
# Predicted: 73.83057685794206 - Actual: 77
# Predicted: 73.93932607197995 - Actual: 74
# Predicted: 56.18895737248482 - Actual: 51
# Predicted: 48.7478284501729 - Actual: 41
# Predicted: 58.55020878022963 - Actual: 60
# Predicted: 56.75959133961206 - Actual: 57
# Predicted: 64.95659712093315 - Actual: 69
# Predicted: 59.09094879523347 - Actual: 56
# Predicted: 66.00751225700111 - Actual: 72
# Predicted: 72.25366067321457 - Actual: 71
# Predicted: 52.12278739763338 - Actual: 55
# Predicted: 74.55702567553574 - Actual: 73
# Predicted: 77.12804115967914 - Actual: 77
# Predicted: 79.58686424358615 - Actual: 74
# Predicted: 14.707049091786509 - Actual: 10
# Predicted: 76.55230207698769 - Actual: 77
# Predicted: 63.084228133834664 - Actual: 62
# Predicted: 65.17127171409139 - Actual: 68
# Predicted: 61.837461123620066 - Actual: 67
# Predicted: 84.21799935356455 - Actual: 75
# Predicted: 64.6051827112145 - Actual: 75
# Predicted: 67.0839070576911 - Actual: 69
# Predicted: 32.037317040974486 - Actual: 30
# Predicted: 86.43106721914612 - Actual: 82
# Predicted: 83.23278292386469 - Actual: 79
# Predicted: 72.08462324389589 - Actual: 70
# Predicted: 75.70810196404167 - Actual: 74
# Predicted: 77.59430283622858 - Actual: 78
# Predicted: 58.525056337667124 - Actual: 58
# Predicted: 71.7055463533162 - Actual: 73
# Predicted: 75.17197116640685 - Actual: 74
# Predicted: 78.81149468487956 - Actual: 83
# Predicted: 52.28684104943937 - Actual: 52
# Predicted: 80.392767032502 - Actual: 73
# Predicted: 90.67564070568056 - Actual: 92
# Predicted: 41.45468775325071 - Actual: 43
# Predicted: 82.67788287381467 - Actual: 87
# Predicted: 79.88717053417157 - Actual: 79
# Predicted: 61.13173774457142 - Actual: 66
# Predicted: 88.72416428712272 - Actual: 90
# Predicted: 77.46225191034931 - Actual: 81
# Predicted: 68.77701840666124 - Actual: 69
# Predicted: 50.19052194951175 - Actual: 52
# Predicted: 68.00703070469656 - Actual: 73
# Predicted: 93.34806422152118 - Actual: 89
# Predicted: 62.13560026082085 - Actual: 64
# Predicted: 87.75026658016633 - Actual: 90
# Predicted: 53.197703624162536 - Actual: 54
# Predicted: 53.30202461347267 - Actual: 56
# Predicted: 59.15616387817362 - Actual: 57
# Predicted: 71.74864694380649 - Actual: 77
# Predicted: 91.23521378446941 - Actual: 98
# Predicted: 52.37719080505873 - Actual: 57
# Predicted: 60.66134598664804 - Actual: 65
# Predicted: 46.868018799308565 - Actual: 44
# Predicted: 58.697274891075864 - Actual: 60
# Predicted: 36.415517170149855 - Actual: 37
# Predicted: 75.92001674232931 - Actual: 73
# Predicted: 69.80944234684063 - Actual: 74
# Predicted: 64.95325451222101 - Actual: 69
# Predicted: 66.08762038025488 - Actual: 64
# Predicted: 81.05925922269692 - Actual: 77
# Predicted: 70.12708482400127 - Actual: 74
# Predicted: 88.6948971971637 - Actual: 85
# Predicted: 21.923113834666232 - Actual: 19
# Predicted: 77.04555391021071 - Actual: 71
# Predicted: 92.59554613326038 - Actual: 97
# Predicted: 60.22775804260068 - Actual: 57
# Predicted: 67.31376143334961 - Actual: 70
# Predicted: 35.11127804940086 - Actual: 32
# Predicted: 67.80765827176366 - Actual: 64
# Predicted: 59.48043640668436 - Actual: 59
# Predicted: 67.56862865608987 - Actual: 67
# Predicted: 78.34222788294056 - Actual: 71
# Predicted: 69.94176198272228 - Actual: 70

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
# Out:
# Mean Absolute Error: 3.174564343542829
# Mean Squared Error: 15.393227002335799
